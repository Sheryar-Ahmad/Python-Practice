# %%
import pandas as pd

mydataset={'car':["BMW","Volvo","Ford"],
           'passing':[3,7,2]
           }

myvar=pd.DataFrame(mydataset)

print(myvar)
# Out:
#      car  passing
# 0    BMW        3
# 1  Volvo        7
# 2   Ford        2

# %%
import pandas as pd

dataset={'Car':["Toyota","Suzuki","Ferrari","Mercedes","BMW","Bugatti","Pagani","Lamborgini","Mehran","Corolla"],
          'Colour':["Red","Blue","Yellow","White","Orange","Pink","Green","violet","Brown","Black"],
         'Fuel':["Diesel","Gas","Petrol","High Ocatane","Diesel","Gas","Petrol","High Ocatane","CNG","Gas"],
         'CarID':[111,222,333,444,555,666,777,888,999,000],
         'Price':[100000,200000,300000,400000,500000,600000,700000,800000,9000000,1100000]
         }

result=pd.DataFrame(dataset)
print(result)

# here all the set would have equal element if there are 10 elements so every feature would have the 10 elements
# Out:
#           Car  Colour          Fuel  CarID    Price
# 0      Toyota     Red        Diesel    111   100000
# 1      Suzuki    Blue           Gas    222   200000
# 2     Ferrari  Yellow        Petrol    333   300000
# 3    Mercedes   White  High Ocatane    444   400000
# 4         BMW  Orange        Diesel    555   500000
# 5     Bugatti    Pink           Gas    666   600000
# 6      Pagani   Green        Petrol    777   700000
# 7  Lamborgini  violet  High Ocatane    888   800000
# 8      Mehran   Brown           CNG    999  9000000
# 9     Corolla   Black           Gas      0  1100000

# %%
import pandas as pd

a=[1,7,2]
myvar=pd.Series(a,index=["x","y","z"])  # label means the name of the element and we use in the dataset
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %% [markdown]
# CSV FILE READING

# %%
import pandas as pd
#df=pd.read_csv("/content/test-data.csv")

#print(pd.options.display.max_rows) # it shows that how much rows can the pandas shows us

#print(df.head(2))         #df.head() function shows the first 5 rows of the csv files

#print(df.to_string())    # it shows the whole csv files

#print(df.tail())         # it shows the last 5 rows of the csv file

# it removes all the empty cells from the csv file
#newfile=df.dropna()
#print(newfile.to_string())


#Remove all rows with NULL values
#df.dropna(inplace = True)
#print(df.to_string())


#Replace NULL values with the number 130
#df=pd.read_csv("/content/test-data.csv")
#df.fillna(130,inplace=True)
#print(df.to_string())




#Replace NULL values in the Specific columns with the number 30
#df=pd.read_csv("/content/test-data.csv")
#df["Transmission"].fillna(130,inplace=True)
#print(df.to_string())


#Finding the Mean, Median and Mode
#df=pd.read_csv("/content/test-data.csv")
#x=df["Price"].mean()
#print(x)

#y=df["Price"].median()
#print(y)

#z=df["Price"].mode()
#print(z)



df=pd.read_csv("/content/test-data.csv")
print(df.info())
print(df.to_string())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1011 entries, 0 to 1010
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               1011 non-null   int64
#  1   Kilometers_Driven  1011 non-null   int64
#  2   Fuel_Type          1011 non-null   int64
#  3   Transmission       1011 non-null   int64
#  4   Owner_Type         1011 non-null   int64
#  5   Mileage            1011 non-null   float64
#  6   Engine             1011 non-null   int64
#  7   Power              1011 non-null   float64
#  8   Seats              1011 non-null   int64
#  9   Price              1011 non-null   float64
# dtypes: float64(3), int64(7)
# memory usage: 79.1 KB
# None
#       Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  Mileage  Engine   Power  Seats  Price
# 0     2011              46000          1             0           1    18.20    1199   88.70      5   4.50
# ...
