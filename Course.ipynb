# %%
raise Exception("System is not responding")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_3034/590095020.py in <cell line: 0>()
# ----> 1 raise Exception("System is not responding")
#
# Exception: System is not responding

# %%
raise KeyError('You have type wrong button')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3034/582156702.py in <cell line: 0>()
# ----> 1 raise KeyError('You have type wrong button')
#
# KeyError: 'You have type wrong button'

# %%
#class someexception(Exception): pass

try:
    x=int(input("Enter the first Number: "))

    y=int(input("Enter the second Number: "))

    print(x/y)
except ZeroDivisionError:
    print('The second number is zero!')
# Out:
# Enter the first Number: 20
# Enter the second Number: 0
# The second number is zero!
