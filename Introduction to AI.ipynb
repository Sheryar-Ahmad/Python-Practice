# %% [markdown]
# Introduction

# %%
print("Sheheryar ahmad")
print("FA24-BSE-002")
print("gpa: 3.72")
# Out:
# Sheheryar ahmad
# FA24-BSE-002
# gpa: 3.72

# %%
print("First Ai lab")
# Out:
# First Ai lab
